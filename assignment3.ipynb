# %% [markdown]
# THIRD ASSIGNMENT :

# %% [markdown]
# a. Integer & Float Mix :
#     Create an integer a and a float b.
#     Perform addition, subtraction, multiplication, and division on them.
#     Print the results and observe the type of each result with type().

# %%
a = 6
b = 7.59

# Addition :
sum = a + b
print(f"The sum of {a} and {b} is {sum}")
print(type(sum))

# Subtraction :
sub = a - b
print(f"The subtraction between {a} and {b} is {sub}")
print(type(sub))


# Multiplication :
mul = a * b
print(f"The multiplication of {a} and {b} is {mul}")
print(type(mul))

# Division :
div = a / b
print(f"The division between {a} and {b} is {div}")
print(type(div))
# Out:
# The sum of 6 and 7.59 is 13.59
# <class 'float'>
# The subtraction between 6 and 7.59 is -1.5899999999999999
# <class 'float'>
# The multiplication of 6 and 7.59 is 45.54
# <class 'float'>
# The division between 6 and 7.59 is 0.7905138339920948
# <class 'float'>

# %% [markdown]
# b. Large Integers & Type :
#     Assign a very large integer to a variable (e.g., in the billions).
#     Print it and confirm its type is still int in Python or not.

# %%
a = 1000000000000000000
print(a)
print(type(a)) # Yes, the data type is still integer
# Out:
# 1000000000000000000
# <class 'int'>

# %% [markdown]
# c. Complex Number Basics :
#     Create a complex number z = 3 + 4j.
#     Print its real part, imaginary part, and confirm its type is complex.
#     Perform a basic arithmetic operation with another complex number (e.g., (3 + 4j) + (1 + 2j)).

# %%
z = 3 + 4j
print(z.real)
print(z.conjugate())
print(type(z))

z1 = 3 + 4j
z2 = 1 + 2j
sum = z1 + z2
print(f"The sum of two complex number is {sum}")
# Out:
# 3.0
# (3-4j)
# <class 'complex'>
# The sum of two complex number is (4+6j)

# %% [markdown]
# d. Boolean from Comparisons :
#     Create two variables, m = 10 and n = 15.
#     Define status = (m > n) and print status.
#     Confirm type(status) is bool.
#     Assign status = (m != n) and print again.

# %%
m = 10
n = 15.
status = (m > n)
print(status)
print(type(status))
status1 = (m != n)
print(status)
# Out:
# False
# <class 'bool'>
# False

# %% [markdown]
# e. String Creation & Indexing :
#     Create a string text = "HelloWorld".
#     Print the first and last characters using positive and negative indexing.
#     Comment on the total length of the string.

# %%
text = "HelloWorld"
print(text[0 : -1])
print(len(text))
# Out:
# HelloWorl
# 10

# %%
# The total length of the string is 10

# %% [markdown]
# f. String Slicing :
#     With lang = "PythonProgramming", print the substring from index 2 to 8.
#     Print the substring from the start up to index 5.
#     Print the entire string in reverse using slicing.

# %%
lang = "PythonProgramming"
print(lang[0:6])
print(lang[::-1])
# Out:
# Python
# gnimmargorPnohtyP

# %% [markdown]
# g. String Methods :
#     Let phrase = " Hello, Python World! ".
#     Demonstrate strip(), upper(), and replace() on this string.
#     Print the results and comment on immutability of strings in Python.

# %%
phrase = " Hello, Python World!"
print(phrase.strip())
print(phrase.upper())
print(phrase.replace("World", "Programming"))
# Out:
# Hello, Python World!
#  HELLO, PYTHON WORLD!
#  Hello, Python Programming!

# %% [markdown]
# h. String Formatting :
#      Create two variables: name = "Alice" and score = 95.
#      Print: "Alice scored 95 points." using two methods (concatenation and an f-string or str.format()).

# %%
name = "Alice"
score = 95
print(name + " scored " + str(score) + " points") # Integer can be added with string so used str to convert int to string
print(f"{name} scored {score} points")
# Out:
# Alice scored 95 points
# Alice scored 95 points

# %% [markdown]
# i. Boolean Operations in Expressions :
#     Write a small expression using and, or, and not with boolean values.
#     Example: result = not(True and False) or (5 > 3).
#     Print result and explain how Python evaluated the expression.

# %%
result = not(True and False) or (5 > 3) 
print(result)
# Out:
# True

# %%
# Output becomes True because or statement gives True even the only one statement  gives the True statement

# %% [markdown]
# j. List Creation & Access :
#     Create a list of 5 different integers.
#     Print the first item, middle item, and last item using indexing.

# %%
lst = [10, 14, 18, 21, 26]
print(lst[0])
print(lst[2])
print(lst[-1])
# Out:
# 10
# 18
# 26

# %% [markdown]
# k. List Insertion & Deletion
#     Start with a list num = [10, 20, 30, 40].
#     Insert 25 at index 2.
#     Remove the last element.
#     Print the updated list.

# %%
num = [10, 20, 30, 40]
print(num.insert(1, 25))
print(num.pop())
print(num)
# Out:
# None
# 40
# [10, 25, 20, 30]

# %% [markdown]
# l. List Slicing :
#     Given letters = ["a", "b", "c", "d", "e"], print the slice that contains only ["b", "c", "d"].
#     Print the slice that omits the first and the last element.

# %%
letters = ["a", "b", "c", "d", "e"]
print(letters[1:4])
print(letters[1:-1])
# Out:
# ['b', 'c', 'd']
# ['b', 'c', 'd']

# %% [markdown]
# m. Sorting & Reversing :
#     Create a list of random integers.
#     Sort the list in ascending order and print it.
#     Reverse the sorted list and print again.

# %%
lst = [10, 9, 14, 6, 89]
lst.sort()
print(lst)
lst.reverse()
print(lst)
# Out:
# [6, 9, 10, 14, 89]
# [89, 14, 10, 9, 6]

# %% [markdown]
# n. Combining Lists
#     Let list1 = [1, 2, 3] and list2 = [4, 5, 6].
#     Combine them into a single list and print.
#     Demonstrate two ways: using + and using .extend().

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]

# Using + Operator :
combine_2 = list1 + list2
print(combine_2)

# Using .extend() :
combine = list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# o. Aggregating List Values :
#     Create a list of floats, e.g., [2.5, 3.6, 1.2, 5.0].
#     Print the sum, minimum, and maximum of that list using built-in functions.

# %%
list = [2.5, 3.6, 1.2, 5.0]
print(sum(list)) # sum of the floats
print(min(list)) # Minimum value of the list
print(max(list)) # Maximum value of the list
# Out:
# 12.3
# 1.2
# 5.0

# %% [markdown]
# p. Tuple Creation :
#     Create a tuple t = (10, 20, "Hello", True).
#     Print the tuple and confirm its type with type(t).

# %%
t = (10, 20, "Hello", True)
print(t)
print(type(t))
# Out:
# (10, 20, 'Hello', True)
# <class 'tuple'>

# %% [markdown]
# q. Tuple Indexing & Slicing :
#     Print the first two elements of t using slicing.
#     Print the last element of t using negative indexing.

# %%
print(t[0:2])
print(t[-1])
# Out:
# (10, 20)
# True

# %% [markdown]
# r. Tuple Unpacking :
#     Suppose t2 = ("Tom", 25, "Engineer").
#     Unpack it into three separate variables: name, age, profession.
#     Print these variables individually.

# %%
t2 = ("Tom", 25, "Engineer")
name, age, profession = t2
print(name)
print(age)
print(profession)
# Out:
# Tom
# 25
# Engineer
