# %% [markdown]
# Attributes and Methods:

# %%
z = 3 - 4j
type(z)
# Out:
# complex

# %%
z.real
z.imag
# Out:
# 4.0

# %%
z.conjugate()
# Out:
# (3+4j)

# %% [markdown]
# Type Conversion:

# %%
a = "40000"
int(a)
# Out:
# 40000

# %%
a = 4
a1 = a ** 2
a1
# Out:
# 16
